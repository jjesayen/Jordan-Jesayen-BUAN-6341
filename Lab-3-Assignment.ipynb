# %% [markdown]
# # Lab 3 Optional Notebook Pre-Flow: Leakage-Safe Linear Models for Regression
#
# This notebook is an optional research and prototyping workspace. Use it only to inspect the dataset, try code ideas, visualize intermediate results, and plan your approach to the Lab 3 problems.
#
# This notebook is **not** the final graded submission.
#
# Move final code into `Lab-3-Assignment.py`, move written answers into `Lab-3-Report.md`, and save referenced outputs under `artifacts/`.
#
# In this pre-flow, you may prototype how to:
# - load and audit the Car Prices Poland dataset
# - create train, validation, and final test splits
# - test preprocessing and feature-engineering ideas before moving them into reusable functions
# - verify manual linear-regression mechanics on a small subset
# - compare scikit-learn Ridge/Lasso settings with manual validation loops
# - run a bounded H2O-3 GLM comparison

# %% [markdown]
# ## Table of Contents
#
# ### PART 1: Data Exploration and Regression Framing (10 points)
# - **Problem 1.1:** Load, Clean, and Audit Dataset (4 points)
# - **Problem 1.2:** Target Distribution and Feature Review (4 points)
# - **Problem 1.3:** Regression Baseline Risk Notes (2 points)
#
# ### PART 2: Leakage-Safe Preprocessing and Feature Engineering (30 points)
# - **Problem 2.1:** Create Train, Validation, and Final Test Splits (5 points)
# - **Problem 2.2:** Implement `fit_preprocessing` and `transform_preprocessing` (10 points)
# - **Problem 2.3:** Encoding Strategy for High-Cardinality Categories (8 points)
# - **Problem 2.4:** Feature Engineering with Training-Only State (5 points)
# - **Problem 2.5:** Leakage Audit and Feature Matrix Checks (2 points)
#
# ### PART 3: Linear Regression Mechanics From Scratch (20 points)
# - **Problem 3.1:** Manual Prediction Equation on a Small Subset (5 points)
# - **Problem 3.2:** Manual Regression Metrics (6 points)
# - **Problem 3.3:** Compare Manual Calculations to scikit-learn (5 points)
# - **Problem 3.4:** Mechanics Reflection (4 points)
#
# ### PART 4: Linear-Model Experiments and Runtime-Aware Model Selection (25 points)
# - **Problem 4.1:** Baseline scikit-learn Linear Regression (5 points)
# - **Problem 4.2:** Ridge and Lasso Validation Loops (8 points)
# - **Problem 4.3:** Residual Diagnostics and Coefficient Review (4 points)
# - **Problem 4.4:** Bounded H2O-3 GLM Comparison (5 points)
# - **Problem 4.5:** Final Test Evaluation (3 points)
#
# ### PART 5: Comparison, Artifacts, and Reflection (15 points)
# - **Problem 5.1:** Cross-Framework Model Comparison (5 points)
# - **Problem 5.2:** Coefficient and Residual Interpretation (5 points)
# - **Problem 5.3:** Required Artifact Summary and Reflection (5 points)

# %% [markdown]
# ## Optional Notebook Imports
#
# Use this optional notebook section only for exploratory imports while prototyping. Put final imports and setup code near the top of `Lab-3-Assignment.py`.

# %%
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import Lasso, LinearRegression, Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

warnings.filterwarnings("ignore")

RANDOM_STATE = 42
TARGET = "price"
DATA_PATH = Path("datasets/Car_Prices_Poland.csv")
ARTIFACT_DIR = Path("artifacts")
FIGURE_DIR = ARTIFACT_DIR / "figures"
TABLE_DIR = ARTIFACT_DIR / "tables"
FIGURE_DIR.mkdir(parents=True, exist_ok=True)
TABLE_DIR.mkdir(parents=True, exist_ok=True)


def rmse_score(y_true, y_pred):
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))


def regression_metrics(y_true, y_pred):
    return {
        "mae": mean_absolute_error(y_true, y_pred),
        "rmse": rmse_score(y_true, y_pred),
        "r2": r2_score(y_true, y_pred),
    }

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 1.1: Load, Clean, and Audit Dataset (4 points)
#
# 1. Load `datasets/Car_Prices_Poland.csv`.
# 2. Display shape, columns, data types, and first rows.
# 3. Identify and drop the extra index-like first column.
# 4. Report final cleaned shape.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 1.2: Target Distribution and Feature Review (4 points)
#
# 1. Confirm `price` is numeric.
# 2. Plot and summarize `price`.
# 3. Separate numeric and categorical predictors.
# 4. Report categorical cardinality and identify high-cardinality columns.
# 5. Save at least one artifact under `artifacts/`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Discussion:**
#
# Write 4-6 lines in `Lab-3-Report.md` on target distribution shape, outliers, and cardinality challenges.

# %% [markdown]
# ## Problem 1.3: Regression Baseline Risk Notes (2 points)
#
# Identify the simple mean-target baseline you will use after splitting and explain why baseline performance matters.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2.1: Create Train, Validation, and Final Test Splits (5 points)
#
# Create train, validation, and final test splits from the cleaned CSV. Do not fit preprocessing before the split.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 2.2: Implement `fit_preprocessing` and `transform_preprocessing` (10 points)
#
# Prototype reusable preprocessing functions here, then move final versions into `Lab-3-Assignment.py`. Store training-only state for imputation, encoding, engineered features, scaling, and column order.

# %%
# YOUR CODE HERE

def fit_preprocessing(train_df, y_train):
    preprocessing_state = {}
    return preprocessing_state


def transform_preprocessing(df, preprocessing_state):
    transformed_features = None
    return transformed_features

# %% [markdown]
# ## Problem 2.3: Encoding Strategy for High-Cardinality Categories (8 points)
#
# Compare at least two strategies for one high-cardinality feature. Report feature count, approximate runtime, validation MAE, validation RMSE, and unknown-category fallback.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 2.4: Feature Engineering with Training-Only State (5 points)
#
# Create at least three engineered features, including a transformation, an interaction, and an aggregation or statistical feature computed from training rows only.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 2.5: Leakage Audit and Feature Matrix Checks (2 points)
#
# Create a leakage audit table and verify train, validation, and final test matrices have identical columns and no missing values.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 3.1: Manual Prediction Equation on a Small Subset (5 points)
#
# Fit a small linear model on 2-3 numeric predictors, then manually compute predictions for at least 10 validation rows using the intercept and coefficients.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 3.2: Manual Regression Metrics (6 points)
#
# Implement manual MAE/RMSE calculations on the small subset and compare them to scikit-learn metric functions.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 3.3: Compare Manual Calculations to scikit-learn (5 points)
#
# Report the maximum absolute difference between manual predictions and scikit-learn predictions and save the comparison table.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 3.4: Mechanics Reflection (4 points)
#
# Write 6-8 lines in `Lab-3-Report.md` explaining what the mechanics exercise revealed.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 4.1: Baseline scikit-learn Linear Regression (5 points)
#
# Train baseline linear regression, report train and validation metrics, and save validation residual/actual-vs-predicted plots.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 4.2: Ridge and Lasso Validation Loops (8 points)
#
# Use explicit loops over candidate alpha values for Ridge and Lasso. Select one final scikit-learn model using validation evidence.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 4.3: Residual Diagnostics and Coefficient Review (4 points)
#
# Create diagnostics for the selected scikit-learn model and interpret residual and coefficient patterns.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 4.4: Bounded H2O-3 GLM Comparison (5 points)
#
# Start a bounded H2O cluster, train one baseline GLM and one regularized GLM, compare validation metrics, and shut down H2O.

# %%
# YOUR CODE HERE
# import h2o
# from h2o.estimators.glm import H2OGeneralizedLinearEstimator
# h2o.init(name="ML_Project_Cluster", max_mem_size="4G", nthreads=4, verbose=False)
# h2o.cluster().shutdown(prompt=False)

# %% [markdown]
# ## Problem 4.5: Final Test Evaluation (3 points)
#
# Evaluate the selected scikit-learn model and selected H2O model once on the final test split.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 5.1: Cross-Framework Model Comparison (5 points)
#
# Create a summary table containing final scikit-learn and H2O metrics on validation and final test data.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 5.2: Coefficient and Residual Interpretation (5 points)
#
# Interpret influential coefficients, residual patterns, one pricing-strategy takeaway, and one next modeling step.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Problem 5.3: Required Artifact Summary and Reflection (5 points)
#
# Create an artifact summary table and write the final reflection in `Lab-3-Report.md`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Final Submission Checklist
#
# Before submitting, make sure you have:
#
# - [ ] Completed final code in `Lab-3-Assignment.py`
# - [ ] Created `Lab-3-Report.md` from `Lab-3-Report-Template.md`
# - [ ] Filled in your name and NetID in `Lab-3-Report.md`
# - [ ] Saved referenced plots, tables, metrics, or other outputs under `artifacts/`
# - [ ] Run `python Lab-3-Assignment.py` from the lab-local `.venv`
# - [ ] Verified the final files on GitHub after pushing
# - [ ] Left this notebook out of the final submission unless your instructor explicitly asked for it
